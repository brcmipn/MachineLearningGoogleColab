# %% [markdown]
# <a href="https://colab.research.google.com/github/brcmipn/MachineLearningGoogleColab/blob/main/ImportarArchivo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hola mundo3")
# Out:
# Hola mundo
